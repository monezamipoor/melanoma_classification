# %%
# !git config --global user.email "ashkan132@gmail.com"
# !git config --global user.name "ashkanfard132"

# %%
import os
from google.colab import drive

# Mount Google Drive
print("🔌 Mounting Google Drive...")
drive.mount('/content/drive')

# Set working directory
base_drive_path = '/content/drive/MyDrive/melanoma'
os.makedirs(base_drive_path, exist_ok=True)
os.chdir(base_drive_path)

# GitHub credentials
GITHUB_TOKEN = "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"  # Replace with your token
GITHUB_USER = "ashkanfard132"
REPO_NAME = "melanoma_classification"
REMOTE_URL = f"https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/monezamipoor/{REPO_NAME}.git"

# SELECT BRANCH HERE
branch = "As-branch"  # ← CHANGE THIS TO YOUR DESIRED BRANCH

# Initialize git if not already
if not os.path.exists(os.path.join(base_drive_path, ".git")):
    print("📦 Initializing new Git repository...")
    # !git init
else:
    print("✅ Git repo already initialized.")

# Add origin if needed
remote_list = os.popen('git remote').read()
if 'origin' not in remote_list:
    print("🔗 Adding origin remote...")
    # !git remote add origin {REMOTE_URL}
else:
    print("🔗 Remote 'origin' already set.")

# Fetch and checkout selected branch
print(f"📥 Fetching '{branch}' from origin...")
# !git fetch origin {branch}

print(f"🔀 Checking out '{branch}' branch...")
# !git checkout -B {branch} origin/{branch}

print(f"✅ Repository ready at '{branch}' branch.")
# Out:
# 🔌 Mounting Google Drive...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Git repo already initialized.
# 🔗 Remote 'origin' already set.
# 📥 Fetching 'As-branch' from origin...
# From https://github.com/monezamipoor/melanoma_classification
#  * branch              As-branch  -> FETCH_HEAD
# 🔀 Checking out 'As-branch' branch...
# error: Your local changes to the following files would be overwritten by checkout:
# 	model.py
# Please commit your changes or stash them before you switch branches.
# Aborting
# ✅ Repository ready at 'As-branch' branch.

# %%
# !git add data.py main.py model.py
# !git add options/default-as1.yml options/default-as2.yml
# # if you haven’t yet added your .gitignore edits:
# !echo -e "logs/\nwandb/\n__pycache__/" >> .gitignore
# !git add .gitignore

# !git commit -m "Update model.py and .gitignore for augmentation changes"
# Out:
# fatal: pathspec 'options/default-as1.yml' did not match any files
# [As-branch b9ffd468] Update model.py and .gitignore for augmentation changes
#  1 file changed, 3 insertions(+)

# %%
# !git remote -v
# Out:
# origin	https://git@github.com/monezamipoor/melanoma_classification.git (fetch)
# origin	https://git@github.com/monezamipoor/melanoma_classification.git (push)

# %%
# !git push -u origin As-branch
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
import os
print("Current working directory:", os.getcwd())
print("Files in the directory:", os.listdir())
# Out:
# Current working directory: /content/drive/MyDrive/melanoma_classification
# Files in the directory: ['mel_data.zip', '.git', 'main.py', 'metrics.py', 'model.py', 'options', 'requirements.txt', 'utils.py', '__pycache__', 'checkpoints', 'logs', 'sample_submission.csv', 'melanoma_classification.ipynb', 'data.py', 'train', '.ipynb_checkpoints']

# %%
# !unzip /content/drive/MyDrive/mel_data.zip -d /content/Melanoma

# %%
# !pip install -r requirements.txt

# %%
import timm
models_list = timm.list_models(filter='swin*', pretrained=True)
print(models_list)
# Out:
# ['swin_base_patch4_window7_224.ms_in1k', 'swin_base_patch4_window7_224.ms_in22k', 'swin_base_patch4_window7_224.ms_in22k_ft_in1k', 'swin_base_patch4_window12_384.ms_in1k', 'swin_base_patch4_window12_384.ms_in22k', 'swin_base_patch4_window12_384.ms_in22k_ft_in1k', 'swin_large_patch4_window7_224.ms_in22k', 'swin_large_patch4_window7_224.ms_in22k_ft_in1k', 'swin_large_patch4_window12_384.ms_in22k', 'swin_large_patch4_window12_384.ms_in22k_ft_in1k', 'swin_s3_base_224.ms_in1k', 'swin_s3_small_224.ms_in1k', 'swin_s3_tiny_224.ms_in1k', 'swin_small_patch4_window7_224.ms_in1k', 'swin_small_patch4_window7_224.ms_in22k', 'swin_small_patch4_window7_224.ms_in22k_ft_in1k', 'swin_tiny_patch4_window7_224.ms_in1k', 'swin_tiny_patch4_window7_224.ms_in22k', 'swin_tiny_patch4_window7_224.ms_in22k_ft_in1k', 'swinv2_base_window8_256.ms_in1k', 'swinv2_base_window12_192.ms_in22k', 'swinv2_base_window12to16_192to256.ms_in22k_ft_in1k', 'swinv2_base_window12to24_192to384.ms_in22k_ft_in1k', 'swinv2_base_window1
# ...

# %%
# !python main.py --opt default-as1.yml

# %%
# !python main.py --opt default-as2.yml
