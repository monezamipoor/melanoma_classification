# %%
# !git config --global user.email "ashkan132@gmail.com"
# !git config --global user.name "ashkanfard132"

# %%
import os
from google.colab import drive

print("Mounting Google Drive...")
drive.mount('/content/drive')

# Set your base path for the repository folder.
base_drive_path = '/content/drive/MyDrive/melanoma_classification'
os.chdir(base_drive_path)

# Check if the repository is initialized
if os.path.exists(os.path.join(base_drive_path, '.git')):
    branch = "As-branch"
    print(f"Git repository exists. Switching to branch {branch}...")
    # !git checkout {branch}
    # !git pull origin {branch}
else:
    print("Initializing git repository...")
    # !git init
    # !git remote add origin https://github.com/monezamipoor/melanoma_classification.git
    # !git remote set-url origin https://ashkanfard132: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@github.com/monezamipoor/melanoma_classification.git


    # !git fetch
    # If you want to start on your branch, you can create and check it out:
    # !git checkout -b As-branch origin/As-branch 2>/dev/null || git checkout -b As-branch
# Out:
# Mounting Google Drive...
# Mounted at /content/drive
# Git repository exists. Switching to branch As-branch...
# Already on 'As-branch'
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !git pull origin As-branch
# !git rebase --continue

# !git add melanoma_classification.ipynb
# !git commit -m "Update jupyter2"
# !git pull --rebase origin As-branch
# Out:
# fatal: No rebase in progress?
# [As-branch 63a5a2a5] Update jupyter2
#  1 file changed, 5491 insertions(+)
#  create mode 100644 melanoma_classification.ipynb
# From https://github.com/monezamipoor/melanoma_classification
#  * branch              As-branch  -> FETCH_HEAD
# Current branch As-branch is up to date.

# %%
# !rm -rf .git/rebase-merge

# %%
# !git merge --abort
# Out:
# fatal: There is no merge to abort (MERGE_HEAD missing).

# %%
# !git status
# !git remote set-url origin git@github.com:monezamipoor/melanoma_classification.git
# Out:
# On branch As-branch
# nothing to commit, working tree clean

# %%
# Stage all changes
# !git add melanoma_classification.ipynb

# Commit changes with your message
# !git commit -m "Update notebook"

# Push your changes to the remote branch
# !git push --force origin As-branch
# Out:
# On branch As-branch
# nothing to commit, working tree clean
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !git checkout As-branch
# Out:
# Already on 'As-branch'

# %%
import os
print("Current working directory:", os.getcwd())
print("Files in the directory:", os.listdir())
# Out:
# Current working directory: /content/drive/MyDrive/melanoma_classification
# Files in the directory: ['mel_data.zip', '.git', 'main.py', 'metrics.py', 'model.py', 'options', 'requirements.txt', 'utils.py', '__pycache__', 'checkpoints', 'logs', 'sample_submission.csv', 'melanoma_classification.ipynb', 'data.py', 'train', '.ipynb_checkpoints']

# %%
# !unzip /content/drive/MyDrive/mel_data.zip -d /content/Melanoma
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Melanoma/train/ISIC_8512716.jpg
#   inflating: /content/Melanoma/train/ISIC_8513112.jpg
#   inflating: /content/Melanoma/train/ISIC_8513649.jpg
#   inflating: /content/Melanoma/train/ISIC_8514170.jpg
#   inflating: /content/Melanoma/train/ISIC_8514989.jpg
#   inflating: /content/Melanoma/train/ISIC_8515165.jpg
#   inflating: /content/Melanoma/train/ISIC_8515281.jpg
#   inflating: /content/Melanoma/train/ISIC_8515582.jpg
#   inflating: /content/Melanoma/train/ISIC_8515674.jpg
#   inflating: /content/Melanoma/train/ISIC_8516181.jpg
#   inflating: /content/Melanoma/train/ISIC_8516223.jpg
#   inflating: /content/Melanoma/train/ISIC_8516516.jpg
#   inflating: /content/Melanoma/train/ISIC_8516631.jpg
#   inflating: /content/Melanoma/train/ISIC_8516659.jpg
#   inflating: /content/Melanoma/train/ISIC_8516922.jpg
#   inflating: /content/Melanoma/train/ISIC_8517305.jpg
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 960.9/960.9 kB 56.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 74.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 79.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 41.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import timm
models_list = timm.list_models(filter='vit*', pretrained=True)
print(models_list)
# Out:
# ['vit_base_mci_224.apple_mclip', 'vit_base_mci_224.apple_mclip_lt', 'vit_base_patch8_224.augreg2_in21k_ft_in1k', 'vit_base_patch8_224.augreg_in21k', 'vit_base_patch8_224.augreg_in21k_ft_in1k', 'vit_base_patch8_224.dino', 'vit_base_patch14_dinov2.lvd142m', 'vit_base_patch14_reg4_dinov2.lvd142m', 'vit_base_patch16_224.augreg2_in21k_ft_in1k', 'vit_base_patch16_224.augreg_in1k', 'vit_base_patch16_224.augreg_in21k', 'vit_base_patch16_224.augreg_in21k_ft_in1k', 'vit_base_patch16_224.dino', 'vit_base_patch16_224.mae', 'vit_base_patch16_224.orig_in21k', 'vit_base_patch16_224.orig_in21k_ft_in1k', 'vit_base_patch16_224.sam_in1k', 'vit_base_patch16_224_miil.in21k', 'vit_base_patch16_224_miil.in21k_ft_in1k', 'vit_base_patch16_384.augreg_in1k', 'vit_base_patch16_384.augreg_in21k_ft_in1k', 'vit_base_patch16_384.orig_in21k_ft_in1k', 'vit_base_patch16_clip_224.datacompxl', 'vit_base_patch16_clip_224.dfn2b', 'vit_base_patch16_clip_224.laion2b', 'vit_base_patch16_clip_224.laion2b_ft_in1k', 'vit_base_p
# ...

# %%
# !python main.py --opt default.yml
# Out:
# {'dataset': {'image_size': [224, 224], 'augmentations': {'horizontal_flip': 0.4, 'vertical_flip': 0.2, 'random_rotation': 10, 'color_jitter': 0.2, 'image_mix_enabled': True, 'image_mix_type': 'column', 'image_mix_prob': 0.3, 'random_shear': 10, 'shift_vertical': [0.1, 0.1]}, 'dataset_train_path': '/content/Melanoma/train', 'dataset_train_csv': '/content/drive/MyDrive/melanoma_classification/train-small.csv', 'dataset_val_path': '/content/Melanoma/train', 'dataset_test_path': '/content/Melanoma/test', 'batch_size': 16}, 'model': {'backbone': 'resnet50', 'pretrained': True, 'output_neurons': 1, 'dropout_rate': 0.3, 'freeze_backbone': True, 'num_frozen_layers': 3}, 'training': {'optimizer': 'amsgrad', 'learning_rate': 0.001, 'scheduler': 'cosine', 'decay_rate': 0.1, 'step_size': 30, 'epochs': 35, 'warmup_epochs': 5, 'freeze_pretrained': True, 'mixed_precision': False, 'gradient_clipping': 1.0}, 'testing': {'log_dir': './logs', 'model_save_strategy': 'best', 'model_save_metric': ['AUC', 
# ...
